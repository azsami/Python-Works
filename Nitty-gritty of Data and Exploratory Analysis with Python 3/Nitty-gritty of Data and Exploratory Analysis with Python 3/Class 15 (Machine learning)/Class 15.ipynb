# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
a = np.linspace(0,5,11)
b = a ** 2

# %%
plt.plot(a,b, color = 'r')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('This is a chart')
# Out:
# Text(0.5, 1.0, 'This is a chart')

# %% [markdown]
# ### Subplot

# %%
# plt.subplot(nrows, ncols, plot_number)

plt.subplot(1,2,1)
plt.plot(a,b,'r', ls = '--')


plt.subplot(1,2,2)
plt.plot(b,a,'g--', lw = 3)

# %% [markdown]
# ### Matplotlib OOM

# %%
fig = plt.figure()

axes = fig.add_axes([.1, .1, .8, .8])  # left bottom right top (range 0 to 1)

axes.plot(a,b, 'r--', lw = 3)
axes.set_xlabel('X Axis')
axes.set_ylabel('Y Axis')
axes.set_title('This is a chart')
# Out:
# Text(0.5, 1.0, 'This is a chart')

# %%
fig = plt.figure()

ax1 = fig.add_axes([.1, .1, .8, .8])
ax2 = fig.add_axes([.2, .5, .4, .3])


ax1.plot(a,b, 'r--')
ax1.set_xlabel('X Axis for Axis 1')
ax1.set_ylabel('Y Axis for Axis 1')


ax2.plot(b,a, 'g--')
ax2.set_xlabel('X Axis for Axis 2')
ax2.set_ylabel('Y Axis for Axis 2')
# Out:
# Text(0, 0.5, 'Y Axis for Axis 2')

# %%
fig = plt.figure(figsize = (12,5))

ax1 = fig.add_axes([.1, .1, .8, .8])
ax2 = fig.add_axes([.2, .5, .4, .3])


ax1.plot(a,b, 'r--')
ax1.set_xlabel('X Axis for Axis 1')
ax1.set_ylabel('Y Axis for Axis 1')


ax2.plot(b,a, 'g--')
ax2.set_xlabel('X Axis for Axis 2')
ax2.set_ylabel('Y Axis for Axis 2')
# Out:
# Text(0, 0.5, 'Y Axis for Axis 2')

# %%
fig, axes = plt.subplots(1,3, figsize = (12,5))

axes[0].plot(a, a**2, 'r--',   a, a**3, 'g*--')
axes[0].set_title('Plot 1')

axes[1].plot(a, a**3, 'g*--')
axes[1].set_title('Plot 2')

axes[2].plot(a, b)
axes[2].set_title('Plot 3')
# Out:
# Text(0.5, 1.0, 'Plot 3')

# %%
fig, axes = plt.subplots(2,2, figsize = (12,5))

axes[0][0].plot(x,y)

axes[0][1].plot(y,x)

# %% [markdown]
# # Matplotlib Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %% [markdown]
# ## Exercise 2
#
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.
# and plot (x,y) on both axes. And call your figure object to show it.**

# %%
# Out:
# Text(0, 0.5, 'y')

# %%
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Exercise 3
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below. Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig, ax = plt.subplots(1,2)

ax[0].plot(x,y, 'b--', lw=3)
ax[1].plot(x,z, 'r', lw=3)

ax[1].set_xlim([50,75])
ax[0].set_ylim([50,175])
# Out:
# (50, 175)

# %% [markdown]
# # Seaborn

# %% [markdown]
# # Distribution Plots
# * disjointplot
# * joinplot
# * pairplot
# * rugplot
# * kdeplot

# %%
tips = sns.load_dataset('tips')

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Disjointplot

# %%
sns.distplot(tips['total_bill'], kde = False)
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:214: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %% [markdown]
# ### Joint plot
# Kind :
# * scatter
# * reg
# * resid
# * kde
# * hex

# %%
sns.jointplot(x = 'total_bill', y= 'tip', data = tips, kind = 'scatter')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:214: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:214: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %%
sns.jointplot(x = 'total_bill', y= 'tip', data = tips, kind = 'hex')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:214: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:214: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %%
sns.jointplot(x = 'total_bill', y= 'tip', data = tips, kind = 'reg')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:214: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:214: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %%
sns.jointplot(x = 'total_bill', y= 'tip', data = tips, kind = 'kde')

# %%
sns.jointplot(x = 'total_bill', y= 'tip', data = tips, kind = 'resid')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:214: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:214: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %% [markdown]
# ### Pairplot
# * Will plot pair wise relationship across entire dataframe (for numerical columns)
# * To see categorical columns need to use hue

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = 'sex')

# %% [markdown]
# ### Rugplot & Kdeplot

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.kdeplot(tips['total_bill'])

# %%
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill'])

# %% [markdown]
# # Categorical plot
# * factorplot
# * boxplot
# * voilinplot
# * stripplot
# * swarmplot
# * barplot
# * countplot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### barplot and countplot

# %%
sns.barplot(x='sex', y='total_bill', data = tips)
# Out:
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
sns.barplot(x='sex', y='total_bill', data = tips, estimator = np.std)

# %%
sns.barplot(x='sex', y='total_bill', data = tips, estimator = lambda x : x.sum()/x.shape[0])

# %%
sns.countplot(x='sex', data=tips)

# %% [markdown]
# ### boxplot and voilin plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(data = tips, x= 'day', y = 'tip')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
sns.boxplot(data = tips, y= 'day', x = 'tip')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
sns.boxplot(data = tips, x= 'day', y = 'tip', hue = 'sex')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:490: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data[hue_mask])
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:490: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data[hue_mask])
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:490: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data[hue_mask])
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:490: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data[hue_mask])
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:490: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data[hue_mask])
# ...

# %%
sns.violinplot(data = tips, x= 'day', y = 'tip')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:598: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:826: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
sns.violinplot(data = tips, x= 'day', y = 'tip', hue = 'smoker')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:647: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data[hue_mask])
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:942: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])

# %%
sns.violinplot(data = tips, x= 'day', y = 'tip', hue = 'smoker', split = True)
# Out:
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:895: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])
# C:\Anaconda\lib\site-packages\seaborn\categorical.py:915: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %% [markdown]
# ### Stripplot and Swarmplot

# %%
sns.stripplot(data = tips, x= 'day', y = 'total_bill', jitter = True)

# %%
sns.stripplot(data = tips, x= 'day', y = 'total_bill', jitter = True, hue = 'sex')

# %%
sns.swarmplot(data = tips, x= 'day', y = 'total_bill')

# %%
sns.swarmplot(data = tips, x= 'day', y = 'total_bill', color = 'black')
sns.violinplot(data = tips, x= 'day', y = 'total_bill', palette = 'rainbow')

# %%
sns.factorplot(data = tips, x= 'day', y = 'total_bill', kind = 'swarm')

# %% [markdown]
# ## Matrix Plot
# * Heat Map
# * Cluster Map

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), annot = True, cmap = 'Greens')

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights.pivot_table(index = 'month', columns = 'year', values = 'passengers')
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
pivot_flight = flights.pivot_table(index = 'month', columns = 'year', values = 'passengers')

# %%
sns.heatmap(pivot_flight, cmap= 'Blues')

# %%
fig = plt.figure(figsize = (12,5))
axes = fig.add_axes([0,0,1,1])

sns.heatmap(pivot_flight, cmap= 'Blues', annot = True, ax = axes)

# %%
sns.clustermap(pivot_flight, cmap = 'Greens', linecolor = 'Black', linewidth = 1)
