# %%
A= {1,2, 2, 3, 4, 40, "True"}

len(A)
# Out:
# ['komola', 'narikel', 'lichu']

# %%
mySet = set()

print(dir(mySet))


# help(mySet.add)
# Out:
# ['__and__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
mySet.add(5)

mySet.add('Jayanta')

mySet.add(5 +5.5j)

mySet


len(mySet)
# Out:
# 3

# %%
help(mySet.discard)
# Out:
# Help on built-in function discard:
#
# discard(...) method of builtins.set instance
#     Remove an element from a set if it is a member.
#
#     If the element is not a member, do nothing.

# %%
help(mySet.remove)
# Out:
# Help on built-in function remove:
#
# remove(...) method of builtins.set instance
#     Remove an element from a set; it must be a member.
#
#     If the element is not a member, raise a KeyError.

# %%
mySet.discard(6)

# %%
try:
  mySet.remove(6)
except KeyError:
  pass

# %%
help(mySet.clear)
# Out:
# Help on built-in function clear:
#
# clear(...) method of builtins.set instance
#     Remove all elements from this set.

# %%
A
# Out:
# {1, 2, 3, 4, 40, 'True'}

# %%
A.clear()

len(A)
# Out:
# 0

# %%
odd = {1,3,5,7,9}

even = {2,4,6,8,10}

prime = {2,3,5,7}

composite = {4,6,8,9,10}

# %%
# dir(odd)

# help(odd.union)

odd.intersection(prime)
# Out:
# {3, 5, 7}

# %%
a = list()
b = [1,2,2,3,3]

print(a)
print(b)
# Out:
# []
# [1, 2, 2, 3, 3]

# %%
myList = ['aam','jaam','kathal','komola','narikel','lichu']

myList
# Out:
# ['aam', 'jaam', 'kathal', 'komola', 'narikel', 'lichu']

# %%
len(myList)
# Out:
# 6

# %%
myList[len(myList)-3]
# Out:
# 'komola'

# %%
myList[-3]
# Out:
# 'komola'

# %%
myList[ 1 : 6 ]
# Out:
# ['jaam', 'kathal', 'komola', 'narikel', 'lichu']

# %%
myList[ -4 : -1 ]
# Out:
# ['kathal', 'komola', 'narikel']

# %%
print(dir(myList))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
# print(myList)

# myList = myList.append(10)

# print(myList)




myList = ['jaam', 'kathal', 'komola', 'narikel', 'lichu']

print(type(myList))


# help(append)
# Out:
# <class 'list'>

# %%
help(myList.append)
# Out:
# Help on built-in function append:
#
# append(...) method of builtins.list instance
#     L.append(object) -> None -- append object to end

# %%
print(myList)

myList.append(10)

print(myList)
# Out:
# ['jaam', 'kathal', 'komola', 'narikel', 'lichu']
# ['jaam', 'kathal', 'komola', 'narikel', 'lichu', 10]

# %%
a = [1,2,3]

a[0]
# Out:
# 1

# %%
myList.extend(a)

# %%
print(myList)
# Out:
# ['jaam', 'kathal', 'komola', 'narikel', 'lichu', 1, 2, 3]

# %%
myDict = {'name' : 'Jaynta', 
          'male' : True,
          'height' : 1.70}

myDict2 = dict(name = 'sarker', female = False)



myDict
# Out:
# {'height': 1.7, 'male': True, 'name': 'Jaynta'}

# %%
print(dir(myDict))
# Out:
# ['__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
myDict['BMI']


# a[100]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-64ffb5cbcb5b> in <module>()
# ----> 1 myDict['BMI']
#       2
#       3
#       4 # a[100]
#
# KeyError: 'BMI'

# %%
try:
  print(myDict['name'])
except KeyError:
  print('Dont Exist')
# Out:
# Jaynta

# %%
'BMI' in myDict
# Out:
# False

# %%
if 'BMI' in myDict:
  print(myDict['BMI'])
else:
  print('Dont Exist')
# Out:
# Dont Exist

# %%
help(myDict.get)
# Out:
# Help on built-in function get:
#
# get(...) method of builtins.dict instance
#     D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.

# %%
print(myDict.get('BMI', 'Dont Exist'))
# Out:
# Dont Exist

# %%
'its true ' if 1==0 else 'not true'
# Out:
# 'not true'

# %%
myList = [1,2,3,4,5]

myTuple = (1,2,3,4,5)

print(type(myList))
print(type(myTuple))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
print(dir(myList))

print('_' * 1000)

print(dir(myTuple))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# ...

# %%
import sys

print(sys.getsizeof(myList))

print(sys.getsizeof(myTuple))
# Out:
# 104
# 88

# %%
import timeit

listTime = timeit.timeit(stmt = "[1,2,3,4,5]", number= 1000000000)


tupleTime = timeit.timeit(stmt = "(1,2,3,4,5)", number= 1000000000)


print(listTime)
print(tupleTime)
# Out:
# 50.511788904999776
# 11.40714565000053

# %%
print('Jayanta')
print('Jayanta')
print('Jayanta')
# Out:
# Jayanta
# Jayanta
# Jayanta

# %%
for i in range(2,10,3):
  print('Jayanta', i)
# Out:
# Jayanta 2
# Jayanta 5
# Jayanta 8

# %%
list(range(2,10,3))
# Out:
# [2, 5, 8]

# %%
for elem in myList:
  print (elem)
# Out:
# jaam
# kathal
# komola
# narikel
# lichu

# %%
x = 0

while x <= 10:
  print('jayanta ', x)
  
  x = x + 1
# Out:
# jayanta  0
# jayanta  1
# jayanta  2
# jayanta  3
# jayanta  4
# jayanta  5
# jayanta  6
# jayanta  7
# jayanta  8
# jayanta  9
# jayanta  10

# %%
A={1,3,4,'e'}
B={3,4,7,9}

A and B
# Out:
# {3, 4, 7, 9}
