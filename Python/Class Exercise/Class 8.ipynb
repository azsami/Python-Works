# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.23.4'

# %% [markdown]
# # Data Frame

# %% [markdown]
# # Series

# %% [markdown]
# # Practise
# ### Get only the NOC column using both the ['..'] and dot notation. What type is this object?

# %%
import pandas as pd
oo = pd.read_csv('olympics.csv', skiprows=4)

# %%
oo.NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
# 5        GRE
# 6        HUN
# 7        GRE
# 8        GRE
# 9        AUT
# 10       GRE
# 11       USA
# 12       HUN
# 13       USA
# 14       GER
# 15       USA
# 16       GBR
# 17       FRA
# 18       AUS
# 19       USA
# 20       GBR
# 21       USA
# 22       USA
# 23       GRE
# 24       AUS
# 25       HUN
# 26       GRE
# 27       USA
# 28       GRE
# 29       USA
#         ...
# 29186    KAZ
# 29187    UZB
# 29188    RUS
# 29189    ARM
# 29190    KOR
# 29191    RUS
# 29192    AZE
# 29193    KAZ
# 29194    KGZ
# 29195    RUS
# 29196    AZE
# 29197    BLR
# 29198    UKR
# 29199    FRA
# 29200    KGZ
# 29201    FRA
# 29202    BUL
# 29203    GEO
# 29204    CHN
# 29205    TUR
# 29206    ITA
# 29207    HUN
# 29208    KAZ
# 29209    USA
# 29210    RUS
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
oo['NOC']
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
# 5        GRE
# 6        HUN
# 7        GRE
# 8        GRE
# 9        AUT
# 10       GRE
# 11       USA
# 12       HUN
# 13       USA
# 14       GER
# 15       USA
# 16       GBR
# 17       FRA
# 18       AUS
# 19       USA
# 20       GBR
# 21       USA
# 22       USA
# 23       GRE
# 24       AUS
# 25       HUN
# 26       GRE
# 27       USA
# 28       GRE
# 29       USA
#         ...
# 29186    KAZ
# 29187    UZB
# 29188    RUS
# 29189    ARM
# 29190    KOR
# 29191    RUS
# 29192    AZE
# 29193    KAZ
# 29194    KGZ
# 29195    RUS
# 29196    AZE
# 29197    BLR
# 29198    UKR
# 29199    FRA
# 29200    KGZ
# 29201    FRA
# 29202    BUL
# 29203    GEO
# 29204    CHN
# 29205    TUR
# 29206    ITA
# 29207    HUN
# 29208    KAZ
# 29209    USA
# 29210    RUS
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %% [markdown]
# ### Get the Edition, City, Athlete Name and Medal columns. What type is this object?

# %%
a = oo['Edition']
b= oo['City']
c= oo['Athlete']
d = oo['Medal']
oo
# oo[['Edition'],['City'],['Athlete'],['Medal']]
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# 16      Athens     1896  Athletics        Athletics
# ...

# %%
# a = ["Edition","City",]
oo[['Edition','City','Athlete','Medal']]
type(oo[['Edition','City','Athlete','Medal']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
type(c)
# Out:
# pandas.core.series.Series

# %%
type(d)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Data input

# %% [markdown]
# ## Overview and validation of data
# ### Shape

# %%
oo.shape[1]
# Out:
# 10

# %% [markdown]
# ### head() and tail()

# %% [markdown]
# ### info()

# %% [markdown]
# # Basic Analysis
# ### value_counts()
#
# #### Find how many medals have been given each year ?

# %% [markdown]
# #### In the history of olympics how many medals have been given to men and women?

# %%
oo['Edition'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        1896
# 1        1896
# 2        1896
# 3        1896
# 4        1896
# 5        1896
# 6        1896
# 7        1896
# 8        1896
# 9        1896
# 10       1896
# 11       1896
# 12       1896
# 13       1896
# 14       1896
# 15       1896
# 16       1896
# 17       1896
# 18       1896
# 19       1896
# 20       1896
# 21       1896
# 22       1896
# 23       1896
# 24       1896
# 25       1896
# 26       1896
# 27       1896
# 28       1896
# 29       1896
#          ...
# 29186    2008
# 29187    2008
# 29188    2008
# 29189    2008
# 29190    2008
# 29191    2008
# 29192    2008
# 29193    2008
# 29194    2008
# 29195    2008
# 29196    2008
# 29197    2008
# 29198    2008
# 29199    2008
# 29200    2008
# 29201    2008
# 29202    2008
# 29203    2008
# 29204    2008
# 29205    2008
# 29206    2008
# 29207    2008
# 29208    2008
# 29209    2008
# 29210    2008
# 29211    2008
# 29212    2008
# 29213    2008
# ...

# %% [markdown]
# ### sort_values()
# #### Generate a series of athlete's name and sort them by their name.

# %%
oo["Athlete"].sort_values(ascending = True)
# Out:
# 651                    AABYE, Edgar
# 2849          AALTONEN, Arvo Ossian
# 2852          AALTONEN, Arvo Ossian
# 7716       AALTONEN, Paavo Johannes
# 7730       AALTONEN, Paavo Johannes
# 7773       AALTONEN, Paavo Johannes
# 7709       AALTONEN, Paavo Johannes
# 8563       AALTONEN, Paavo Johannes
# 28460              AAMODT, Ragnhild
# 3436               AANING, Alf Lied
# 19062         AARDENBURG, Willemien
# 22769             AARDEWIJN, Pepijn
# 22267          AARONES, Ann Kristin
# 3437                  AAS, Karl Jan
# 2601           AAS, Thomas Valentin
# 28134              ABAJO, Jose Luis
# 27691              ABAKUMOVA, Maria
# 27983           ABALMASAU, Aliaksei
# 28417                    ABALO, Luc
# 24202         ABANDA ETONG, Patrice
# 21538            ABARCA, Jose Maria
# 27125                 ABAS, Stephen
# 16390     ABASCAL GARCIA, Alejandro
# 16806    ABASCAL GOMEZ, Jose Manuel
# 26049             ABASSOVA, Tamilla
# 28418                   ABATI, Joel
# ...

# %%
oo['Athlete'].value_counts()
# Out:
# LATYNINA, Larisa                 18
# PHELPS, Michael                  16
# ANDRIANOV, Nikolay               15
# SHAKHLIN, Boris                  13
# ONO, Takashi                     13
# MANGIAROTTI, Edoardo             13
# NURMI, Paavo                     12
# KATO, Sawao                      12
# NEMOV, Alexei                    12
# TORRES, Dara                     12
# FISCHER, Birgit                  12
# THOMPSON, Jenny                  12
# OSBURN, Carl Townsend            11
# CHUKARIN, Viktor Ivanovich       11
# SPITZ, Mark                      11
# BIONDI, Matthew                  11
# COUGHLIN, Natalie                11
# CASLAVSKA, Vera                  11
# GEREVICH, Aladar                 10
# SCHERBO, Vitaly                  10
# VAN ALMSICK, Franziska           10
# ASTAKHOVA, Polina                10
# KELETI, Agnes                    10
# DITYATIN, Aleksandr              10
# HALL, Gary Jr.                   10
# LEWIS, Carl                      10
# ...

# %% [markdown]
# #### Sort the whole data frame by yer of perticipation and athlete's name.

# %%
# oo.head()
oo.sort_values( by = ['Edition',"Athlete"])
# Out:
#           City  Edition          Sport       Discipline  \
# 7       Athens     1896       Aquatics         Swimming
# 82      Athens     1896     Gymnastics      Artistic G.
# 110     Athens     1896     Gymnastics      Artistic G.
# 111     Athens     1896     Gymnastics      Artistic G.
# 48      Athens     1896        Cycling     Cycling Road
# 19      Athens     1896      Athletics        Athletics
# 134     Athens     1896         Tennis           Tennis
# 140     Athens     1896         Tennis           Tennis
# 13      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 84      Athens     1896     Gymnastics      Artistic G.
# 99      Athens     1896     Gymnastics      Artistic G.
# 66      Athens     1896        Fencing          Fencing
# 4       Athens     1896       Aquatics         Swimming
# 5       Athens     1896       Aquatics         Swimming
# 8       Athens     1896       Aquatics         Swimming
# ...

# %% [markdown]
# ### Filtering DataFrame by Boolean indexing
#
# #### Find all Athlete's records who have won gond medals.

# %% [markdown]
# #### Find all women Athlete's records who have won silver medals.

# %% [markdown]
# #### Find all records of the femous USA's woman athlete named Florence.

# %% [markdown]
# # Practise
#
# #### Find all records of athlete named 'OWENS, Jesse' ?

# %%
oo.head
# Out:
# <bound method NDFrame.head of           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# ...

# %%
oo[oo['Athelete'] == 'OWENS, Jesse']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Athelete'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-77a8983ff5ec> in <module>
# ...

# %% [markdown]
# #### Find all records of athletes who have won the men's gold medals in singles badminton over the history of Olympics? Sort the results alphabetically by the player's  names.

# %% [markdown]
# #### Which three countries have won the most medals from 1984 to 2008 ?

# %% [markdown]
# #### Find all Records of the male gold medal winners for the 100m event over the history of olympics. List the results starting with the most recent. Show the Olympic City, Edition, Athlete and the country they represent.
